# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("fraction3.csv",encoding="CP949")

# %%
for name in data.columns[3:]:
    sum = data[name].sum()
    data[name] = data[name] * 100

# %%
# Out:
# 0       사직동
# 1       삼청동
# 2       부암동
# 3       평창동
# 4       무악동
#        ...
# 420    둔촌1동
# 421    둔촌2동
# 422    암사1동
# 423    천호2동
# 424      길동
# Name: 동, Length: 425, dtype: object

# %%
data.to_csv("data_regular.csv")

# %%
test
# Out:
# array([2867.31946038])

# %%
data['공원수'] = data['공원수'] / size

# %%
data
# Out:
#      Unnamed: 0  자치구     동       공원수       유치원      초등학교       중학교      고등학교  \
# 0             3  종로구   사직동  0.012861  0.925972  0.720201  0.462986  0.771644
# 1             4  종로구   삼청동  0.015579  1.121706  0.872438  0.560853  0.934755
# 2             5  종로구   부암동  0.023735  1.708908  1.329151  0.854454  1.424090
# 3             6  종로구   평창동  0.092744  6.677541  5.193643  3.338770  5.564617
# 4             7  종로구   무악동  0.003764  0.271016  0.210790  0.135508  0.225847
# ..          ...  ...   ...       ...       ...       ...       ...       ...
# 419         446  강동구  둔촌1동  0.010942  1.459130  0.972753  0.673444  0.523790
# 420         447  강동구  둔촌2동  0.011655  1.554290  1.036194  0.717365  0.557950
# 421         448  강동구  암사1동  0.012131  1.617731  1.078487  0.746645  0.580724
# 422         449  강동구  천호2동  0.018672  2.490037  1.660024  1.149248  0.893859
# 423         450  강동구    길동  0.025808  3.441643  2.294429  1.588451  1.235462
#
# ...
